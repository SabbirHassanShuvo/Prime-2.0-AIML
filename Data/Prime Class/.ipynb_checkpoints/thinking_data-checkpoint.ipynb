# %%
import json

# %%
# load the data
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("stroe_data.json")
print(data)
# Out:
# {'cells': [{'cell_type': 'code', 'execution_count': None, 'id': '6ee40bc7-1549-47d4-80f8-f5422a86db90', 'metadata': {}, 'outputs': [], 'source': ['{\n', '  "products": [\n', '    {\n', '      "id": 1,\n', '      "name": "Men\'s Casual T-Shirt",\n', '      "slug": "mens-casual-tshirt",\n', '      "price": 499,\n', '      "discount_price": 399,\n', '      "stock": 50,\n', '      "brand": "Cylore",\n', '      "category": "Clothing",\n', '      "sub_category": "T-Shirts",\n', '      "description": "Comfortable cotton casual t-shirt for everyday use.",\n', '      "thumbnail": "https://example.com/images/tshirt1.jpg",\n', '      "images": [\n', '        "https://example.com/images/tshirt1.jpg",\n', '        "https://example.com/images/tshirt2.jpg"\n', '      ],\n', '      "ratings": 4.5,\n', '      "reviews_count": 120,\n', '      "is_featured": true,\n', '      "is_new": true,\n', '      "created_at": "2026-06-01"\n', '    },\n', '    {\n', '      "id": 2,\n', '      "name": "Women\'s Sty
# ...
