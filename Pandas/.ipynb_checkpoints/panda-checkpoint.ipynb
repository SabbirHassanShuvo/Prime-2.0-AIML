# %%
import pandas as pd

# %%
info = {
    "Name": ["Sabbir", "Toyob", "Ajom", "Rakib"],
    "CGPA": [9.5, 7.8, 9.0, 8.0]
}

df = pd.DataFrame(info)

print(df)
# Out:
#   Cell In[2], line 2
#     "Name" = ["Sabbir", "Toyob", "Ajom", "Rakib"],
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
