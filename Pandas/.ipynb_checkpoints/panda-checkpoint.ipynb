# %%
import pandas as pd

# %%
info = {
    "Name": ["Sabbir", "Toyob", "Ajom", "Rakib"],
    "CGPA": [9.5, 7.8, 9.0, 8.0]
}

df = pd.DataFrame(info)

print(df)
# Out:
#      Name  CGPA
# 0  Sabbir   9.5
# 1   Toyob   7.8
# 2    Ajom   9.0
# 3   Rakib   8.0

# %%
df
