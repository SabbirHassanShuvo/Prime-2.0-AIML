# %%
import pandas as pd

# %%
info = {
    "Name": ["Sabbir", "Toyob", "Ajom", "Rakib"],
    "CGPA": [9.5, 7.8, 9.0, 8.0]
}

df = pd.DataFrame(info)

print(df)
# Out:
#      Name  CGPA
# 0  Sabbir   9.5
# 1   Toyob   7.8
# 2    Ajom   9.0
# 3   Rakib   8.0

# %%
df
# Out:
#      Name  CGPA
# 0  Sabbir   9.5
# 1   Toyob   7.8
# 2    Ajom   9.0
# 3   Rakib   8.0

# %%
s = pd.Series([23, 24, 25, 26], index=["Ajom", "Rakib", "Toyob", "Suvas"])
print(s)

print(s["Rakib"])
print(s["Toyob"])
print(1)
# Out:
# Ajom     23
# Rakib    24
# Toyob    25
# Suvas    26
# dtype: int64
# 24
# 25
